# %%
import matplotlib.pyplot as plt

# Data
num_threads = [1, 2, 4, 8, 16]
execution_time = [0.411987, 0.309518, 0.272043, 0.266876, 0.32952]
speedup = [1, 1.33106, 1.51442, 1.54374, 1.25026]

# Calculate standard deviation for error bars 
std_deviation = [0.05, 0.03, 0.02, 0.01, 0.05]

# Plotting with error bars
plt.errorbar(num_threads, speedup, yerr=std_deviation, fmt='o-', label='Speedup')
plt.xlabel('Number of Threads')
plt.ylabel('Speedup')
plt.title('Speedup vs. Number of Threads')
plt.legend()
plt.grid(True)
plt.show()
